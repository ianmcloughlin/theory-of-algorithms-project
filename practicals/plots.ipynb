# %% [markdown]
# # Plots
#
# ***

# %%
# Numerical arrays.
import numpy as np

# Plots.
import matplotlib.pyplot as plt

# %% [markdown]
# ## $f(x) = x^2 + 1$
#
# ***

# %%
# Range of x values.
x = np.linspace(-4.0, 4.0, 1000)

# Corresponding f(x) values.
f = x**2 + 1

# %%
# Create a plot.
fig, ax = plt.subplots(figsize=(10, 6))

# Plot f(x).
ax.plot(x, f, label='$x^2+1$')

# Show the legend.
ax.legend();

# %% [markdown]
# ## $g(x) = 3x^6 + x^4 +1$
#
# ***

# %%
# Range of x values.
x = np.linspace(-4.0, 4.0, 1000)

# Corresponding g(x) values.
g = 3 * x**6 + x**4 + 1

# %%
# Create a plot.
fig, ax = plt.subplots(figsize=(10, 6))

# Plot g(x).
ax.plot(x, g, label='$3x^6 + x^4 +1$')

# Show the legend.
ax.legend();

# %% [markdown]
# ## $h(x) = x^2$ and $j(x) = 2^x$
#
# ***

# %%
# Range of x values.
x = np.linspace(0.0, 100.0, 1000)

# Corresponding h(x) values.
h = x**2

# Corresponding j(x) values.
j = 2**x

# %%
# Create a plot.
fig, ax = plt.subplots(figsize=(10, 6))

# Plot h(x).
ax.plot(x, h, label='$x^2$')

# Plot j(x).
ax.plot(x, j, label='$2^x$')

# Show the legend.
ax.legend();

# %% [markdown]
# ## $g(f(x))$
#
# ***

# %%
# Range of x values.
x = np.linspace(0.0, 100.0, 1000)

# Corresponding f(x) values.
f = x**2 + 1

# %%
# Corresponding g(f(x)) values.
gof = 3 * f**6 + f**4 + 1

# %%
# Create a plot.
fig, ax = plt.subplots(figsize=(10, 6))

# Plot f(x).
ax.plot(x, f, label='$f(x) = x^2+1$')

# Plot g(x).
ax.plot(x, g, label='$g(x) = 3x^6 + x^4 +1$')

# Plot g(f(x)).
ax.plot(x, gof, label='$g(f(x)) = 3(x^2 + 1)^6 + (x^2 + 1)^4 +1$')

for i in range(1, 13):
  # Plot x^i.
  ax.plot(x, x**i, label=f'$x^{i}$')

# Plot of 2^x.
ax.plot(x, 2**x, label='$2^x$')

# Show the legend.
ax.legend();

# %% [markdown]
# ## Lecture 2023-03-15
#
# ***

# %%
# Values of n.
n = np.arange(0.0, 3.0, 0.01)

# Create a plot.
fig, ax = plt.subplots(figsize=(10, 6))

# Plot.
ax.plot(n, 5*(n**2) + 1, label='$5n^2+1$')

# Plot.
ax.plot(n, n**2, label='$n^2$')

# Plot.
ax.plot(n, 6*(n**2), label='$6n^2$')

# Show the legend.
ax.legend();

# %% [markdown]
# ## Lecture 2023-03-23
#
# ***

# %%
# Values of n.
n = np.arange(0.0, 10.0, 0.01)

# Create a plot.
fig, ax = plt.subplots(figsize=(10, 6))

# Plot g(n).
ax.plot(n, n**2, label='$n^2$')

# Plot f(n).
ax.plot(n, 0.5 * n**2 + 1.5 * n + 1, label=r'$\frac{1}{2} n^2 + \frac{3}{2} n + 1$')

# Plot.
# ax.plot(n, 6*(n**2), label='$6n^2$')

# Show the legend.
ax.legend();

# %% [markdown]
# ***
#
# ## End
