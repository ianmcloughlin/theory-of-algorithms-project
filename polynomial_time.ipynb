# %% [markdown]
# # The Polynomial Time Complexity Class
#
# ***

# %% [markdown]
# ## Formal Languages
#
# ***

# %% [markdown]
# A formal language is...

# %%
# Example Language
L = {'00', '01', '10', '11'}

L
# Out:
# {'00', '01', '10', '11'}

# %% [markdown]
# A language L is in $P$ if and only if there exists a deterministic Turing machine $M$, such that [1]:
#
# - $M$ runs in polynomial time on all inputs,
# - $\forall x \in L: M(x) = 1$ and
# - $\forall x \notin L: M(x) = 0$.

# %% [markdown]
# ## Polynomials
#
# ***

# %%
# Numerical arrays.
import numpy as np

# Plots.
import matplotlib.pyplot as plt

# %%
n = np.arange(0, 100, 2)

p = n**2 + 2*n + 1

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(n, p, label='$n^2 + 2n + 1$')

ax.legend();

# %% [markdown]
# ## References
#
# [1]
# : **P (complexity);** Wikipedia, The Free Encyclopedia; 3 Oct. 2022; Web. 26 Jan. 2023; https://en.wikipedia.org/wiki/P_(complexity)

# %% [markdown]
# ***
#
# #### End
